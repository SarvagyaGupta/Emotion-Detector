# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('2018-E-c-En-train.txt', sep="\t", error_bad_lines=False)

# %%
emotions = ["anger", "disgust", "fear", "joy", "sadness", "surprise"]
count = 0
dataframes = []
for em in emotions:
    c = pd.DataFrame(columns = ["Tweet", "emotion"])
    df = data[data[em] == 1]
    df = df[["Tweet", em]]
    df = df.rename(columns={em: "emotion"})
    for index_label, row_series in df.iterrows():
        # For each row update the 'Bonus' value to it's double
        df.at[index_label , 'emotion'] = count
        c = c.append({"Tweet":df.at[index_label , 'Tweet'], 
                      "emotion": df.at[index_label , 'emotion']}, ignore_index=True)
        df.drop(index_label, inplace=True)        
    count += 1
    dataframes.append(c)

# %%
#now it is time to take care of the neutral
data = pd.read_csv("text_emotion.csv")
data = data.rename(columns={"sentiment" : "emotion", "content" : "Tweet"})
data = data[["Tweet", "emotion"]]
data = data[data["emotion"] == 'neutral']
for index_label, row_series in data.iterrows():
    if(data.at[index_label, 'emotion'] == "neutral"):
        data.at[index_label , 'emotion'] = 6
dataframes.append(data)

# %%
main = pd.concat(dataframes).reset_index(drop=True)    
main["emotion"].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=object)

# %%
import nltk
nltk.download('punkt')
import re
import string
punctuation = string.punctuation
from nltk.corpus import stopwords
stopwords = stopwords.words("english")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/aviralsharma/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def cleanTweet(tweet):
    tweet = tweet.lower()
    #maybe we want to remove the twitter handle as well
    #removing the punctuations
    tweet = "".join(x for x in tweet if x not in punctuation)
    #removing the stop words
    individualWords = tweet.split()
    individualWords = [w for w in individualWords if w not in stopwords]
    tweet = " ".join(individualWords)
    #removing certain common occuring words
    tweet = re.sub('rt', '', tweet)
    return tweet

# %%
main["clean tweets"] = main["Tweet"].apply(cleanTweet)
main.to_csv("tweets.csv")
main
# Out:
#                                                    Tweet emotion  \
# 0      @Max_Kellerman  it also helps that the majorit...       0
# 1      My roommate: it's okay that we can't spell bec...       0
# 2      Rooneys fucking untouchable isn't he? Been fuc...       0
# 3      @BossUpJaee but your pussy was weak from what ...       0
# 4      S/O to the girl that just hit my car...not onl...       0
# 5      @bt_uk broadband is shocking regretting signin...       0
# 6      People you need to look up the definition of p...       0
# 7              @BitchestheCat Look at those teef! #growl       0
# 8      Star trek online has a update to download oh f...       0
# 9      i cant stop. i finished - dejected. luckily no...       0
# 10     @NHLexpertpicks @usahockey USA was embarrassin...       0
# 11     Your glee filled Normy dry humping of the most...       0
# 12     @zorefx you guys will see what i did in the ne...       0
# 13           What a fucking muppet.  @jRwild1  #stalker.       0
# 14     My cat is bloody lucky the RSPCA weren't open ...       0
# 15     Autocorrect changes ''em' to 'me' which I rese...       0
# 16     I mean I'm not done watching the pilot, but it...       0
# 17     @WaterboysAS I would never strategically vote ...       0
# 18     @Jen_ny69 People will always get offended ever...       0
# 19     @Aliki111 Haters!!! You are low in self worth....       0
# 20     All the young people are so bitter about how t...       0
# 21     @TamraBarney @ShannonBeador @RHOC_KellyDodd Ta...       0
# 22     He accusd India of HR violations in Kashmir BU...       0
# 23     @Kristiann1125 lol wow i was gonna say really?...       0
# 24     im also definitely still bitter about the yell...       0
# 25     @mas_critical The irony is that those protesti...       0
# 26            @loismackey_ @Dory nah way that's horrible       0
# 27     @MaryamNSharif I think just becz u have so muc...       0
# 28     Puzzle investing opening portland feodal popul...       0
# 29                 Brb going to sulk in bed until Friday       0
# ...                                                  ...     ...
# 19842  says gud eve guys.. lets play poker@facebook y...       6
# 19843  @21five would love to hear all of this from a ...       6
# 19844  @RajaSen Sports Bar Shatranjanpoli Rest Ph 264...       6
# 19845                          @kellywilliams4 On what..       6
# 19846                                       is surfin'..       6
# 19847                  @Chris_Hayward go two way mirrors       6
# 19848   @camen_marris I know. I'll have to get some soon       6
